# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

df = pd.read_csv("wine.csv")
print(df.head())
# 컬럼명 확인
print(df.columns)
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735
# Index(['Wine', 'Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols',
#        'Flavanoids', 'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue',
#        'OD', 'Proline'],
#       dtype='object')

# %%
sns.countplot(data = df, x="Wine")
plt.xlabel("Wine Class")
plt.ylabel("Count")
plt.title("Wine Label Distribution")
# Out:
# Text(0.5, 1.0, 'Wine Label Distribution')

# %%
# 레이블 개수 확인 (숫자)
df['Wine'].value_counts()
# Out:
# Wine
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %%
# pairplot를 사용해 변수 간 상관관계 시각화

sns.pairplot(df,
             vars=['Alcohol', 'Malic.acid', 'Ash', 'Proline'],
            hue='Wine')
plt.show()

# %%
# 특정 컬럼의 범위 확인 및 outlier 확인

sns.set_theme(style="whitegrid")
sns.boxplot(x="Ash", data=df, palette="Set3")
plt.title("Wine")
plt.show()
# Out:
# C:\Users\June\AppData\Local\Temp\ipykernel_19348\239381828.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Ash", data=df, palette="Set3")

# %%
y = df['Wine']
y.value_counts()
print(y.head())

X = df.drop('Wine', axis=1)
print(X.head())
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Wine, dtype: int64
#    Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
Y = pd.get_dummies(y).values

# %%
X = X.values

# %%
print(X)
print(y)
# Out:
# [[1.423e+01 1.710e+00 2.430e+00 ... 1.040e+00 3.920e+00 1.065e+03]
#  [1.320e+01 1.780e+00 2.140e+00 ... 1.050e+00 3.400e+00 1.050e+03]
#  [1.316e+01 2.360e+00 2.670e+00 ... 1.030e+00 3.170e+00 1.185e+03]
#  ...
#  [1.327e+01 4.280e+00 2.260e+00 ... 5.900e-01 1.560e+00 8.350e+02]
#  [1.317e+01 2.590e+00 2.370e+00 ... 6.000e-01 1.620e+00 8.400e+02]
#  [1.413e+01 4.100e+00 2.740e+00 ... 6.100e-01 1.600e+00 5.600e+02]]
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#Defining the model 

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam


model = Sequential()

model.add(Dense(10, input_shape=(X_train.shape[1],), activation='relu'))
model.add(Dense(8,activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential_2"
# ?뤴봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?년봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣뵵?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣뵑
# ??u001b Layer (type)                    ??u001b Output Shape           ??u001b       Param # ??n?△봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?뉍봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣븛?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣뵫
# ??dense_8 (Dense)                 ??(None, 10)             ??          140 ??n?쒋??????????????????????????????????쇄?????????????????????????쇄?????????????????n??dense_9 (Dense)                 ??(None, 8)              ??           88 ??n?쒋??????????????????????????????????쇄?????????????????????????쇄?????????????????n??dense_10 (Dense)                ??(None, 6)              ??           54 ??n?쒋??????????????????????????????????쇄?????????????????????????쇄?????????????????n??dense_11 (Dense)                ??(None, 3)              ??           21 ??n?붴??????????????????????????????????닳?????????????????????????닳?????????????????n
#  Total params: 303 (1.18 KB)
#  Trainable params: 303 (1.18 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 5/5 ?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺 1s 54ms/step - accuracy: 0.3169 - loss: 216.4050 - val_accuracy: 0.3889 - val_loss: 143.8079
# Epoch 2/30
# 5/5 ?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺 0s 16ms/step - accuracy: 0.3169 - loss: 197.1137 - val_accuracy: 0.3889 - val_loss: 129.1050
# Epoch 3/30
# 5/5 ?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺 0s 14ms/step - accuracy: 0.3169 - loss: 178.8224 - val_accuracy: 0.3889 - val_loss: 114.9361
# Epoch 4/30
# 5/5 ?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺 0s 29ms/step - accuracy: 0.3169 - loss: 161.6244 - val_accuracy: 0.3889 - val_loss: 101.4043
# Epoch 5/30
# 5/5 ?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺 0s 15ms/step - accuracy: 0.3169 - loss: 145.2265 - val_accuracy: 0.3889 - val_loss: 88.6638
# Epoch 6/30
# 5/5 ?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺 0s 16ms/step - accuracy: 0.3169 - loss: 129.9735 - val_accuracy: 0.3889 - val_loss: 76.7492
# Epoch 7/30
# 5/5 ?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺 0s 16ms/step - accuracy: 0.3169 - loss: 114.7288 - val_accuracy: 0.3889 - val_loss: 65.7032
# Epoch 8/30
# 5/5 ?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺 0s 14ms/step - accuracy: 0.3169 - loss: 101.8121 - val_accuracy: 0.3889 - val_loss: 55.0170
# Epoch 9/30
# 5/5 ?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺?곣봺 0s 16ms/step - accuracy: 0