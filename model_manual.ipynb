# %% [markdown]
# 자주 사용하는 library 및 함수

# %%
# change file type pandas or numpy
import pandas as pd
import numpy as np

path = 'path'

df = pd.read_csv(path)
#df = pd.read_csv(pth, index_col=0) # index_col = 0을 통해서 컬럼 갯수 제거

df.head()

# %%
# 온라인(외부에서) 불러오기
from sklearn import datasets

iris = datasets.load_iris()
iris # 딕셔너리로 load됨

# %%
# training data, test data split

# train_test_split(arrarys, test_size, train_size, random_state, shuffle, stratify)
# arrarys : 배열(numpy, pandas(df))
# test_size : 데이터 셋의 크기 (0.2 > 20%)
# train_size : 학습 데이터 크기 (기본값 None 1-test_size)
# random_state : 데이터를 나눌때 사용되는 난수 시드, 지정하지 않으면 값이 다름(학습 순서에 따라 차이 발생)
# shuffle : 데이터 섞음 여부
# stratify : 레이블을 고려하여 데이터 나눌지 여부 확인 

from sklearn.model_selection import train_test_split

test_size = 0.2
shuffle = True
random_state = 12

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=12)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size,shuffle,random_state)

# %%
# classification
# 분류 모델
# label이 지정된 데이터셋을 사용하여 학습
# binary, multi-class

# LogisticRegression        : S자 형태의 곡선을 이용해 데이터가 특정 클래스에 속할 확률을 계산하여 분류
# DecisionTreeClassifier    : 데이터의 특징을 바탕으로 스무고개처럼 질문을 던져 가지를 치며 분류
# RandomForestClassifier    : 여러 개의 의사결정 나무를 만들고, 그들의 예측 결과를 다수결로 종합하여 분류
# KNeighborsRegressor       : 근처값 확인 k가 근접 갯수 확인 (다다익선이 아니다)
# 각 함수는 모델을 return한다.
# 모델.fit(x,y)를 통해서 학습한뒤 
# predic(x)를 통해서 값을 분류 또는 에측한다
# ex) LogisticRegression(random_state = 0)

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# classification check
from sklearn.metrics import accuracy_score # 정확도
from sklearn.metrics import confusion_matrix #혼동행렬 ==> k fold

accuracy_score(y_test, pred_lr)
confusion_matrix(y_test, pred_lr)

# %%
# regression 
# 회귀 분석
# 연속적인 수치를 예측하는것
# simple, multiple, logistic

# LogisticRegression        : S자 형태의 곡선을 이용해 데이터가 특정 클래스에 속할 확률을 계산하여 분류
# DecisionTreeRegressor     : 데이터의 특징을 바탕으로 스무고개처럼 질문을 던져 가지를 치며 분류
# RandomForestRegressor     : 여러 개의 결정 트리(Decision Tree)를 만들어서 그 예측값들의 평균을 내어 최종 결과를 내놓는 앙상블(Ensemble) 모델
# KNeighborsRegressor       : 근처값 확인 k가 근접 갯수 확인 (다다익선이 아니다)
# 각 함수는 모델을 return한다.
# 모델.fit(x,y)를 통해서 학습한뒤 
# predic(x)를 통해서 값을 분류 또는 에측한다
# ex) LinearRegression()

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
# regression check
from sklearn.metrics import mean_squared_error # 평균제곱오차
mean_squared_error(ly_preds, y_test)

# %% [markdown]
# ## 문제 발생
#
# ### String 입력 문제
#
# | | X (Feature) | y (Label) |
# |------|------|------|
# | |X_train | y_train |
# | |X_test | y_test |
#
# | | Label 필요 | Feature 스케일링 필요 |
# |------|------|------|
# | ML | ✅ | ❌ |
# | DL | ❌ | ❌ |

# %%
import pandas as pd

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# Name 컬럼 인코딩

df['Name_encoded'] = le.fit_transform(df['Name'])
